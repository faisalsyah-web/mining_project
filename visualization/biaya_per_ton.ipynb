# %% [markdown]
# ## Load CSV

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("../Output/rata-rata_per_ton.csv")

# %%
df = df.sort_values("rata_rata_biaya_per_ton_pit")

# %%
hasil = hasil.sort_values("biaya_per_ton")

# %%
plt.figure(figsize=(12, 6))
plt.bar(df["pit_id"].astype(str), df["rata_rata_biaya_per_ton_pit"])
plt.xlabel("Pit ID")
plt.ylabel("Rata Rata Biaya Per Ton")
plt.title("Perbandingan Rata Rata Biaya Per Ton per Pit")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
